# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt

# %%
image_path = "2011_10_03/2011_10_03_drive_0027_sync/image_02/data/0000000000.png"
image = cv2.imread(image_path);

# %%
plt.imshow(image)
plt.show()

# %%
scale_percent = 50
width = int(image.shape[1]*scale_percent/100)
height = int(image.shape[0]*scale_percent/100)
dim = (width,height)
resized = cv2.resize(image,dim,interpolation=cv2.INTER_AREA)
print("Resized image shape : ",resized.shape)
plt.imshow(resized)
plt.show()
# Out:
# Resized image shape :  (188, 620, 3)

# %%
from Dataset.dataset import KittiDataset
dataset = KittiDataset()

# %%
len(dataset)
# Out:
# 4541

# %%
img, label = dataset[30]

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
# change channel order from [3,224,224] to [224,224,3]
img = img = np.transpose(img, (1, 2, 0))

# split concatenated image into two images
img1 = img[:, :, 0:3]
img2 = img[:, :, 3:6]

# %%
img.shape
# Out:
# torch.Size([224, 224, 6])

# %%
plt.imshow(img1)
plt.show()

# %%
plt.imshow(img2)
plt.show()

# %%
label
# Out:
# array([[-5.09810000e-02],
#        [-2.68994000e-02],
#        [ 9.51560000e-01],
#        [ 5.30134481e-03],
#        [ 9.21778659e-04],
#        [-1.11600581e-03]])
